# %%
import  matplotlib.pyplot  as  plt
# %matplotlib inline
import numpy as np

fig1 = plt.figure(figsize = (20, 20))

with open("1.png", 'rb') as map_file:
    map_img = plt.imread(map_file)
with open("2.png", 'rb') as map_file:
    map2_img = plt.imread(map_file)
with open("3.png", 'rb') as map_file:
    map3_img = plt.imread(map_file) 
with open("4.png", 'rb') as map_file:
    map4_img = plt.imread(map_file)

axes1 = fig1.add_axes([-0.08, 0.45, 1, 0.5])
axes1.imshow(map_img)  
plt.axis('off')
axes2 = fig1.add_axes([0.0, 0.0, 0.25, 0.4])
axes2.imshow(map2_img) 
plt.axis('off')
axes3 = fig1.add_axes([0.28, 0.0, 0.24, 0.4])
axes3.imshow(map3_img) 
plt.axis('off')
axes4 = fig1.add_axes([0.55, 0.0, 0.29, 0.4])
axes4.imshow(map4_img) 
plt.axis('off')
plt.savefig('666.png')
plt.show()
